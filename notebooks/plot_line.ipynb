# %%
import sys
import os

# Get the absolute path to the src directory
src_path = os.path.abspath(os.path.join('..', 'src'))
if src_path not in sys.path:
    sys.path.append(src_path)

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from utils.figure_style import FigureStyle
from utils.json_data_reader import JSONDataReader

# Access constants from JSON
json_reader = JSONDataReader('../data/config.json')
sample_names = json_reader.get('sample_names')
group_names = json_reader.get('group_names')
sample_colors = json_reader.get('sample_colors')
group_colors = json_reader.get('group_colors')
fig_dims = json_reader.get('figure_dimensions')
one_third_fig_width = fig_dims.get('one_third_fig_width')
half_fig_width = fig_dims.get('half_fig_width')
full_fig_width = fig_dims.get('full_fig_width')
fig_height_a0 = fig_dims.get('fig_height_a0')
fig_height_a = fig_dims.get('fig_height_a')
fig_height_b = fig_dims.get('fig_height_b')

# %%
# Common setup code here...

# Generate mockup time series data
np.random.seed(5)
time = np.arange(10)
values = np.random.randn(10, 3) + np.array([2, 3, 4])
df_time = pd.DataFrame(values, columns=sample_names)
df_time['Time'] = time
df_melted = df_time.melt(id_vars='Time', var_name='Sample', value_name='Value')

# Create an instance of FigureStyle with custom colors
style_config = FigureStyle(colors=sample_colors)
style_config.apply()

# Create a line plot
fig, ax = plt.subplots(figsize=(half_fig_width, fig_height_a))
sns.lineplot(x='Time', y='Value', hue='Sample', data=df_melted, palette=sample_colors, ax=ax)

# Customize the plot
style_config.set_titles(ax, 'Line Plot 1')
style_config.set_labels(ax, 'Time', 'Value')
style_config.update_legend_style(ax, title='Sample')

# Save the figure
style_config.save_figure('../figures/line_plot1.pdf')

# Show the plot (optional)
plt.show()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped

# %%
# Common setup code here...

# Generate different data
np.random.seed(6)
time = np.arange(15)
values = np.random.randn(15, 3) + np.array([1.5, 2.5, 3.5])
df_time = pd.DataFrame(values, columns=sample_names)
df_time['Time'] = time
df_melted = df_time.melt(id_vars='Time', var_name='Sample', value_name='Value')

# Create an instance of FigureStyle with custom colors
style_config = FigureStyle(colors=sample_colors)
style_config.apply()

# Create a line plot
fig, ax = plt.subplots(figsize=(half_fig_width, fig_height_a))
sns.lineplot(x='Time', y='Value', hue='Sample', data=df_melted, palette=sample_colors, ax=ax)

# Customize the plot
style_config.set_titles(ax, 'Line Plot 2')
style_config.set_labels(ax, 'Time', 'Value')
style_config.update_legend_style(ax, title='Sample')

# Save the figure
style_config.save_figure('../figures/line_plot2.pdf')

# Show the plot (optional)
plt.show()
# Out:
# 1 extra bytes in post.stringData array
# 'created' timestamp seems very low; regarding as unix timestamp
# Zapf NOT subset; don't know how to subset; dropped
# feat NOT subset; don't know how to subset; dropped
# morx NOT subset; don't know how to subset; dropped
